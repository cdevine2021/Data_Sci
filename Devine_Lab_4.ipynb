# %% [markdown]
# <a href="https://colab.research.google.com/github/cdevine2021/Data_Sci/blob/main/Devine_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt
#importing numpy and matplotlib.pyplot so we can use these functions throughout our lab

# %%
x = np.array([12, 17, 18, 23, 56, 37, 48])
#assigning x to these array of random numbers

# %%
# population

# %%
def mean(x):
    return np.sum(x)/x.shape[0]
# defining the mean of x and returning the sum of x and then returning the shape to 0

# %%
def var(x):
    return mean((x - mean(x))**2)
# variables of x and returning the mean of x to a different formula

# %%
def std(x):
    return np.sqrt(var(x))
#creating another defining function that changes the last one we made of variables just this time with the standard deviation

# %%
mean(x)
#finding the mean of x
# Out:
# 30.142857142857142

# %%
var(x)
#variance of x
# Out:
# 247.83673469387756

# %%
std(x)
#finding the standard deviation of x
# Out:
# 15.742831215949613

# %%
x - mean(x)
#taking all the numbers froom the array of x and subrating the mean from them
# Out:
# array([-18.14285714, -13.14285714, -12.14285714,  -7.14285714,
#         25.85714286,   6.85714286,  17.85714286])

# %% [markdown]
# ### Random Number Generator

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus 
# assigning m, b, and n to random numbers

# %%
x = 123456      # seed value
#x equals 123456

# %%
X = np.zeros(50000,)
# X equals np.zeros(50000,)

# %%
x = (m * x + b) % n
#making x equal to the slop formula

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

X /= np.max(X)
# creating a range of x from the slop formula and shaping it X.shape[0]

# %%
plt.plot(X[:100],'.')
#plotting the answers as dots from X[:100],'.'

# %%
plt.hist(X);
#plotting the data of X as a histogram

# %%
plt.hist(X,100);
#same thing as before but now making 100 numbers

# %%
X
#showing what numbers X is equal too
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
#showing what numbers X is equal too
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
#showing what numbers X is equal too
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)
#creating X as it is equal too a random number formula

# %%
plt.hist(X,100);
#creating a histogram with the data and formula we just assigned X to

# %%
np.random.random()
#showing a random number
# Out:
# 0.9605965213575232

# %%
r = np.random.random()
# assigning x to that random number

# %%
r
#showing r without the formula
# Out:
# 0.3580950227002577

# %%
r = np.random.randint(1,10)
#creating a random array of 10 numbers and from that we pick the first

# %%
r
#showing what number it is
# Out:
# 2

# %%
r = np.random.randint(1,10,size=(10,2))
#creating a random array of 10 numbers and from that we pick the first and also adding size restrictions to it

# %%
r
# showing the new r and its array of numbers
# Out:
# array([[5, 6],
#        [3, 6],
#        [4, 3],
#        [6, 5],
#        [3, 5],
#        [7, 3],
#        [4, 7],
#        [8, 7],
#        [7, 4],
#        [2, 3]])

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()
#showing 4 grapghs or plots of the data from a random number and its array of data

# %% [markdown]
# Normal Dist Data

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)
#creating a histogram from the data of n,bins,patches

# %%
bins
#showing the array of numbers that bins is equal too
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)
#plotting a grapgh but only showing one line to show the outline of how the data fluctuates

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)
#showing the outling again but alos putting the data behind it to show how well it lines up with it

# %%
def mean(x):
    return np.sum(x)/x.shape[0]
# defining the mean of x and returning the sum of x and then returning the shape to 0

# %%
def var(x):
    return mean((x - mean(x))**2)
# variables of x and returning the mean of x to a different formula

# %%
def std(x):
    return np.sqrt(var(x))
#creating another defining function that changes the last one we made of variables just this time with the standard deviation

# %%
mean(x)
#showing what the mean of x is
# Out:
# 100.08743095584884

# %%
std(x)
#showing what the standard deviation of x is
# Out:
# 14.948331789981761

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))
#defining the normal pdf with 3 symbols and returning it with this formula

# %%
x = np.linspace(-6,6,1000)
#showing what formula x is equal too

# %%
mu = 0
#saying mu is equal to 0

# %%
sigma = 1
#showing that sigma is equal to 1

# %%
pdf = normal_pdf(x,mu,sigma) 
#Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
#plotting the data we get from the equation from pdf

# %%
def partial_sums(x):#defining the partial sums of x

  y = np.zeros(x.shape)#showing the equation of y and the shape
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y
# for the range of x.shape we put 0 and the sum as well, and after all that we retrun y

# %%
cdf = partial_sums(pdf)
#assigning cdf to equal the partial sums of pdf

# %%
plt.plot(x,cdf,'.');
#plotting the data from cdf instead of pdf

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');
#plotting the data from cdf

# %%
def find_nearest(array, value): #finding nearest array and value

  idx = np.argmin(np.abs(array - value)) #creating a formula and making it equal to idx
  
  return idx #returing idx at the end of it

# %%
find_nearest(cdf, 0.1)
#finding the nearest of cdf
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))
#creating xr and making it equal to a random number within 10000

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]
#creating w and adding a formula and then creating a range of xr.shape[0]

# %%
w.shape
#showing what w.shape is equal too
# Out:
# (10000,)

# %%
plt.hist(w,50);
#plotting a histogram with w and 50

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)
#making num_bins equal to 50 and creating a histogram with a line to show the outline of the data

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt
#importing numpy and matplotlib.pyplot

# %%
z = np.random.randint(0,255,size=(10,10,3))
# making z equal a random array of data with 255 numbers and creating the parameters of the size

# %%
plt.imshow(z)
#showing z

# %%
z = np.zeros((10,10,3))
#changing z to equal a new formula

# %%
plt.imshow(z)
#showing the new z and how its different

# %%
z = 0*np.ones((10,10,3))
#changing z to equal a new formula

# %%
plt.imshow(z)
#showing the new z and how its different

# %%
z = 255*np.ones((10,10,3))
#changing z to equal a new formula

# %%
plt.imshow(z)
#showing the new z and how its different
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)
#chnaging z so we get more than black and white and showing what color it makes

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)
#chnaging z so it shows us a different color

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)
#chnaging z so it shows us a different color

# %%
z = np.ones((10,10,3))

r = np.random.rand()
g = np.random.rand()
b = np.random.rand()

print(r,g,b)

z[:,:,0] = r
z[:,:,1] = g
z[:,:,2] = b

plt.imshow(z);
#changing z even more and randomizing it with different array's and showing the color
# Out:
# 0.24807790454917555 0.8650109910442956 0.3276343579730595

# %%
for i in range(10):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
#here we want to show 10 different colors so we are choosing random array's and pulling colors from them and showinh them
# Out:
# 0.5586182266980704 0.5594456386122482 0.2562441808868948
# 0.3963938216344448 0.9656326569774536 0.428003358988416
# 0.44277362933518605 0.6072295671446113 0.4455913744560339
# 0.6475142954746046 0.5747117524041668 0.9187174158386677
# 0.8277181500022373 0.7094068967822101 0.5779524110711313
# 0.3323445061218834 0.6765001639263071 0.46299708104911164
# 0.8264992218304685 0.46297730236374635 0.01692896723457471
# 0.02339404975726478 0.027944858769867853 0.9685203188520476
# 0.6639971400388327 0.48619448758091754 0.1407893511206394
# 0.3136669979235688 0.13460465092289065 0.5133091085190374

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

z3 = np.hstack((z1,z2))

plt.imshow(z3);
plt.show()
#we are choosing two colors from different array's and showing them but split half and half

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()
#showing 10 split colors from the random array's

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()
#showing 10 split colors from the random array's

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp
#importing all those functions and using that website to create an array of different random colors and show a list then return cmp which is
#the linear color segment map

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'
#inserting an url to pull colors from

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'
#inserting an url to pull colors from

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'
#inserting an url to pull colors from

# %%
im = imageio.imread(url)
#creating im and making it equal to an array of colors from the url

# %%
plt.imshow(im);
#showing the different colors from im

# %%
z = np.random.randint(0,255,size=(10,10))
#creating z to equal a random array for 255 colrs with different size parameters

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();
#showing the color bar and showing z along with colors from the url

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
#showing a mix of colors from the url with different grid patterns

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
#showing a mix of colors from the url with a different grip and shape to them

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
#showing a mix of colors from the url with a different grip and shape to them
